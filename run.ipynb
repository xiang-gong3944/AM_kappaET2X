# %% [markdown]
# # 条件

# %% [markdown]
# ここに実行した内容をまとめる

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os

from model.hubbard_model import HubbardModel
from model import calc, plot
from util import post

# %%
KappaET2X = HubbardModel(n_carrier=6.1, k_mesh=75, U=1, iteration=400, err=1e-6, fineness=5)
calc.spin_conductivity(KappaET2X, "x", "y")
calc.spin_conductivity(KappaET2X, "x", "x")
calc.spin_conductivity(KappaET2X, "y", "y")
plot.fermi_surface(KappaET2X)
plot.band(KappaET2X)
# Out:
# SCF calculation start. N = 6.10, U = 1.00, err < 1.0e-06
# SCF loop converged.  N = 6.10, err < 1.0e-06, loop = 36, delta = 7.51e-01
#
# NSCF calculation start.
# NSCF calculation finished.
#
# kF index calculation start
# kF index calculation finished
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 3.79e-06, ImChi = -5.24e-21
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 2.18e-02, ImChi = -3.55e-20
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 5.83e-04, ImChi = -3.32e-21

# %%
KappaET2X = HubbardModel(n_carrier=6.4, k_mesh=75, U=1, iteration=400, err=1e-6, fineness=5)
calc.spin_conductivity(KappaET2X, "x", "y")
calc.spin_conductivity(KappaET2X, "x", "x")
calc.spin_conductivity(KappaET2X, "y", "y")
plot.fermi_surface(KappaET2X)
plot.band(KappaET2X)
# Out:
# SCF calculation start. N = 6.40, U = 1.00, err < 1.0e-06
# SCF loop converged.  N = 6.40, err < 1.0e-06, loop = 132, delta = 5.24e-01
#
# NSCF calculation start.
# NSCF calculation finished.
#
# kF index calculation start
# kF index calculation finished
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 5.88e-06, ImChi = -1.18e-19
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 3.19e-01, ImChi = 3.88e-19
#
# SpinConductivity calculation start.
# Spin Conductivity calculation finished
# ReChi = 7.40e-03, ImChi = 8.44e-21
